# %% [markdown]
# # April 23 Results
#
# #### These are after removal for attention and for messy eeg
#
# ### 9 month olds : new seg only, all ps!
# #### "908", "909", "910", "912", "913", "914", "916", "917", "919", "920", "921", "923", "924","927", "928", "929", "930", "932"
# - training: 0.1815
#
# - average_trials: .47
#
# - fully_averaged: .56
#
#
# ### 12 month olds : new seg only, all ps!
# - training: 0.2129
#
# - average_trials: .51
#
# - fully_averaged: .56

# %% [markdown]
# # May 11 Results
#
# #### These are after removal for attention and for messy eeg
#
# ### 9 month olds : new seg only
# ####  "908", "909", "912", "913", "914", "916", "917", "919", "920", "921", "924","927", "930"
# Removed: 910, 923, 928, 929, 932 (less than 40 good trials left)
#
# #### Train on raw test on averaged data, (kernel= linear, C=1e-9, max_iter=5000)
#
# - training: 0.23
#
# - average_trials: .456
#
# - fully_averaged: .375
#
# #### Train and Test on subsetting (subset of ps), (kernel = linear, C=1e-9, max_iter=5000)
#
# - raw data set: .53, .54
#
# - averaged_trails: .375, .4375, .5, .46
#
# - fully_averaged: .4375, .5
#
# #### Train and Test on subsetting (subset of data), (kernel = rbf, C=1, max_iter=5000)
#
# - raw data set:
#
# - averaged_trails: .33
#
# Accuracy Score : 0.6666666666666666
# Precision Score : 0.75
# Recall Score : 0.5
# F1 Score : 0.6
# Confusion Matrix :
# [[20  4]
#  [12 12]]
#
# - fully_averaged:
#
#
# ### 12 month olds : new seg only, ps with more than 40 trials each
# #### "109", "111", "112", "115", "124"
#
# #### Train on raw test on averaged data, (C=1e-9, max_iter=5000)
# - training: 0.2298
#
# - average_trials: .438
#
# - fully_averaged: .375
#
# #### Train and Test on subsetting (subset of data), (kernel = rbf, C=1, max_iter=5000)
#
# - raw data set:
#
# - averaged_trails: .375, .66
#
# - fully_averaged:
#
#
# Completely mixed
