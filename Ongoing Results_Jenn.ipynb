# %% [markdown]
# # April 23 Results
#
# #### These are after removal for attention and for messy eeg
#
# ### 9 month olds : new seg only, all ps!
# #### "908", "909", "910", "912", "913", "914", "916", "917", "919", "920", "921", "923", "924","927", "928", "929", "930", "932"
# - training: 0.1815
#
# - average_trials: .47
#
# - fully_averaged: .56
#
#
# ### 12 month olds : new seg only, all ps!
# - training: 0.2129
#
# - average_trials: .51
#
# - fully_averaged: .56

# %% [markdown]
# # May 21 Results
# ### 9 month olds: Train on raw test on averaged data, (kernel= linear, C=1e-9, max_iter=5000)
#
# - training: .35
#
# - average_trials: .5
#
# - fully_averaged: .4375
#
# ### 9 month olds :  (linear, 2/8 fold)
# - raw:
#
# - average_trials:
#
# - fully_averaged:
#
# ### 9 month olds :  (radial, 2/8 fold)
#
# All kids:
# - raw: .51
#
# - average_trials: .55
#
# - fully_averaged: (with old ps we got: .375 with model = SVC(gamma=.001, kernel = 'rbf', C = 100)), second iteration: .50, 3rd: .50, 4th: .43 (but now C =100), 5th: .375
#
# SVC(C=1e-06, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
# New kids:
# - raw:
#
# - average_trials:
#
# - fully_averaged: .625
# model = SVC(gamma=.001, kernel = 'rbf', C = 100)
#
# ### 9 month olds : new seg only
# ####  "908", "909", "912", "913", "914", "916", "917", "919", "920", "921", "924","927", "930"
# Removed: 910, 923, 928, 929, 932 (less than 40 good trials left)

# %% [markdown]
# ### 12 month olds :
# #### Train on raw test on averaged data, (linear, C=1e-9, max_iter=5000)
# - training: .34
#
# - average_trials: .47
#
# - fully_averaged: .56
#
# #### Train on raw test on averaged data, (rbf, c = 1e-9, gamma = .001, max_iter=5000)
# - training: .49
#
# - average_trials: .5
#
# - fully_averaged: .5
#
# #### Train and Test on subsetting (2/8 fold), (kernel = linear)
#
# - raw data set:
#
# - averaged_trails:
#
# - fully_averaged:
#
#
#
# #### Train and Test on subsetting (2/8 fold), (kernel = rbf, max_iter=5000, optimization)
#
# - raw data set: .49 (optimal), .50 (optimal)
# SVC(C=1e-06, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
#
# - averaged_trails: .5 (using inputs from above)
#
# - fully_averaged: .56
#
# ### new seg only, ps with more than 40 trials each
# #### "109", "111", "112", "115", "124"

# %% [markdown]
# ### all kids: (entire window) (optimization takes 46m)
# #### linear, train on avg
# - training: .36
#
# - average_trials: .48
#
# - fully_averaged: .56
#
# #### rbf
# - raw data: .55
#
# - average_trials: .48
#
# - fully_averaged:

# %% [markdown]
# # May 27 : multigroup analysis
#
# ## 12m, 4 groups: people, animals, food, kitchen artifacts
# ### linear kernel
#
# - training (on raw): .49 !! Super high!
#
# - average_trials: .66
#
# - fully_averaged: .43
#
# ## 12m, rbf, 4 groups: people, animals, food, kitchen artifacts
# ### model = SVC(gamma=.001, kernel = 'rbf', C = 1e-6)
#
# - training (on raw): .63 !! Super high!
#
# - average_trials: .63
#
# - fully_averaged: .63
#
# ## 12m, rbf, 4 groups: people, animals, food, kitchen artifacts
# ### model = SVC(gamma=.001, kernel = 'rbf', C = 100)
# ### 8/2 cross validation
#
# - raw data: .66
#
# - average_trials: .68
#
# - fully_averaged: .68
