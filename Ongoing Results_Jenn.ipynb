# %% [markdown]
# # April 23 Results
#
# #### These are after removal for attention and for messy eeg
#
# ### 9 month olds : new seg only, all ps!
# #### "908", "909", "910", "912", "913", "914", "916", "917", "919", "920", "921", "923", "924","927", "928", "929", "930", "932"
# - training: 0.1815
#
# - average_trials: .47
#
# - fully_averaged: .56
#
#
# ### 12 month olds : new seg only, all ps!
# - training: 0.2129
#
# - average_trials: .51
#
# - fully_averaged: .56

# %% [markdown]
# # May 21 Results
# ### 9 month olds: Train on raw test on averaged data, (kernel= linear, C=1e-9, max_iter=5000)
#
# - training: .35
#
# - average_trials: .5
#
# - fully_averaged: .4375
#
#
# ### 9 month olds :  (radial, trian on 80% test on 20% of ps)
#
# All 9m:
# model = SVC(gamma=.001, kernel = 'rbf', C = 100))
# raw:
# - error = [0.5121951219512195,
#  0.5082872928176796,
#  0.5058479532163743,
#  0.513986013986014,
#  0.5260869565217391,
#  0.5109170305676856,
#  0.5059288537549407,
#  0.5272727272727272,
#  0.5093457943925234,
#  0.5166666666666667]
# - avg = .51 (.07)
#
# raw windows:
# - all the same result
#
# average_trials:
# - error [0.525, 0.5125, 0.5125, 0.475, 0.5125, 0.65, 0.5375, 0.5875, 0.5875, 0.475]
# - avg = .53 (.05)
# - windows: .49
#
# fully_averaged:
# - [.375 .50 .50 .43 .375, .4375 .43 .50 .4375 + .375]
# - Avg error= .436 (stdev = .05)
# - windows: .31 (600ms to 1000ms)
#
# SVC(C=1e-06, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)
#
# new kids
# - super bad still
#
#
# ### Cross validations (random subset of data withheld for test):
# #### All 9m
# ##### Linear (max_iter=1000, C=1e-3), 5fold
# raw:
# - [0.50555556 0.5 0.47222222 0.45810056 0.55307263]
# - Accuracy: 0.50 (+/- 0.07)
#
# average_trials:
# - [0.43103448 0.46551724 0.51724138 0.51724138 0.55357143]
# - Accuracy: 0.50 (+/- 0.09)
#
# fully_averaged:
# - [0.5  0.5  0.25 1.   0.5 ]
# - Accuracy: 0.55 (+/- 0.49)
#
#
# ##### Radial SVC(gamma=.001, kernel = 'rbf', C = 1e-6)
# raw:
# - [0.50555556 0.50555556 0.50555556 0.50837989 0.50837989]
# - Accuracy: 0.51 (+/- 0.00)
#
# average_trials:
# - [0.51724138 0.48275862 0.51724138 0.51724138 0.42857143]
# - Accuracy: 0.49 (+/- 0.07)
#
# fully_averaged:
# - [0.5  0.25 0.25 0.   0.  ]
# - Accuracy: 0.20 (+/- 0.37)
#
# #### 9m with more than 40 trials each:
# ##### Radial SVC(gamma=.001, kernel = 'rbf', C = 1e-6)
# raw:
# - [0.51612903 0.51612903 0.51612903 0.51298701 0.51633987]
# - Accuracy: 0.52 (+/- 0.00)
#
# average_trials:
# - [0.57142857 0.57142857 0.38095238 0.5        0.5       ]
# Accuracy: 0.50 (+/- 0.14)
#
# fully_averaged:
# - [0.75 0.5  0.5  0.5  0.5 ]
# Accuracy: 0.55 (+/- 0.20)

# %% [markdown]
# ### 12 month olds :
# #### Train on raw test on averaged data, (linear, C=1e-9, max_iter=5000)
# - training: .34
#
# - average_trials: .47
#
# - fully_averaged: .56
#
# #### Train on raw test on averaged data, (rbf, c = 1e-9, gamma = .001, max_iter=5000)
# - training: .49
#
# - average_trials: .5
#
# - fully_averaged: .5
#
#
# #### Train and Test on subsetting (train on 80% of ps, test on 20% of ps)
# model = SVC(gamma=.001, kernel = 'rbf', C = 1e-6)
# All 12m olds
#
# raw data set:
# - [0.375, 0.4375, 0.5, 0.375, 0.4375, 0.75, 0.5, 0.5, 0.4375, 0.4375]
# - .475 (.1 std dev)
#
#
# averaged_trails:
# - [0.5625, 0.5208, 0.5625, 0.4792, 0.5, 0.5625, 0.6042, 0.5833, 0.4792, 0.4583]
# - 0.53125 (.04)
# - best window: .48
#
#
# fully_averaged:
# - [0.375, 0.4375, 0.5, 0.375, 0.4375, 0.75, 0.5, 0.5, 0.4375, 0.4375]
# - .475 (.1 std dev)
# - best window: best is .38 window
#
#
# model = SVC(gamma=.001, kernel = 'rbf', C = 1e-6)
# new kids: some promise...
#
#
# ### Cross validations (random subset of data withheld for test across subjects):
# #### Linear (max_iter=1000, C=1e-3), 5fold
# raw:
# - [0.47445255 0.44525547 0.49635036 0.53284672 0.44852941]
# - Accuracy: 0.48 (+/- 0.07)
#
# average_trials:
# - [0.26190476 0.38095238 0.52380952 0.52380952 0.375     ]
# - Accuracy: 0.41 (+/- 0.20)
#
# fully_averaged:
# - [0.75 0.5  0.5  0.   0.5 ]
# - Accuracy: 0.45 (+/- 0.49)
#
# #### Radial SVC(gamma=.001, kernel = 'rbf', C = 1e-6)
# raw:
# - [0.50364964 0.50364964 0.50364964 0.50364964 0.5       ]
# - Accuracy: 0.50 (+/- 0.00)
#
# average_trials:
# - [0.38095238 0.5        0.35714286 0.47619048 0.425     ]
# - Accuracy: 0.43 (+/- 0.11)
#
# fully_averaged:
# - [0.5 0.5 0.5 0.  0.5]
# - Accuracy: 0.40 (+/- 0.40)

# %% [markdown]
# ### all kids: (entire window) (optimization takes 46m)
# #### linear, train on avg
# - training: .36
#
# - average_trials: .48
#
# - fully_averaged: .56
#
# #### rbf
# - raw data: .55
#
# - average_trials: .48
#
# - fully_averaged:
#
# ### Cross validations (random subset of data withheld for test):
# #### Radial SVC(gamma=.001, kernel = 'rbf', C = 1e-6)
#
# raw data:
# -[0.50169492 0.50169492 0.50340136 0.50340136 0.50170648]
# - Accuracy: 0.50 (+/- 0.00)
#
# average_trials:
# -[0.5106383  0.44680851 0.44565217 0.47826087 0.5       ]
# - Accuracy: 0.48 (+/- 0.05)
#
# fully_averaged:
# -[0.5 0.5 0.5 0.5 0.5]
# - Accuracy: 0.50 (+/- 0.00)

# %% [markdown]
# # May 27 : multigroup analysis
#
# ## 12m, 4 groups: people, animals, food, kitchen artifacts
# ### linear kernel
#
# - training (on raw): .49 !! Super high!
#
# - average_trials: .66
#
# - fully_averaged: .43
#
# ## 12m, rbf, 4 groups: people, animals, food, kitchen artifacts
# ### model = SVC(gamma=.001, kernel = 'rbf', C = 1e-6)
#
# - training (on raw): .63 !! Super high!
#
# - average_trials: .63
#
# - fully_averaged: .63
#
# ## 12m, rbf, 4 groups: people, animals, food, kitchen artifacts
# ### model = SVC(gamma=.001, kernel = 'rbf', C = 100)
# ### train on 80% ps, test on 20%
#
# - raw data: .66
#
# - average_trials: .68
#
# - fully_averaged: .68

# %% [markdown]
# # First 20 good trials analysis
#
# ## 12m: all kids
# ### tran on raw, predict averaged rbf, gamma=.001, kernel = 'rbf', C = 1e-6)
# - averaged trials: all windows at .5
# - fully averaged:  all windows at .5
#
#
# ### train 80%, predict 20%, gamma=.001, kernel = 'rbf', C = 1e-6)
# - raw : .5
# - averaged trials: .40 is the best in the >600ms windows
# - fully averaged: .25 is the best in the with 100-700ms all really good
# model = SVC(kernel = 'rbf', gamma = .001, C=1e-6)
#
#
#
# ## 9m: all kids
# ### train on raw, predict averaged rbf, gamma=.001, kernel = 'rbf', C = 1e-6)
# - averaged trials: .5 all
# - fully averaged: .5 all
#
# ### train 80%, predict 20%, gamma=.001, kernel = 'rbf', C = 1e-6)
# - raw : .5
# - averaged trials: .41 is the best 100-500ms
# - trial averaged: .31 is best window using 500ms onward
#
# ### kids with at least 40 trials:
# #### train 80%, predict 20%, gamma=.001, kernel = 'rbf', C = 1e-6)
# - raw : .5
# - averaged trials: .42 is the best in 0-500ms
# - trial averaged: .31 is best window using 200ms onward

# %% [markdown]
# ## 1 vs all
# mom vs all
# 9m (gamma=.001, kernel = 'rbf', C=1e-06)
# avg trials
# - .55 (.04)
