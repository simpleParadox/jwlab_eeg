# %% [markdown]
# # Training Model: SVM

# %% [markdown]
# # 9 month olds

# %% [markdown]
# ## 1. Importing libraries ...

# %%
import pandas as pd
import numpy as np
import setup_jwlab
from jwlab.constants import cleaned_data_filepath
from jwlab.ml_prep import prep_ml
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2. Importing 9-Month-Olds..

# %%
#participants = ["904", "905", "906", "909", "910", "912", "908", "913", "914", "916", "917", "919", "920", "921", "923", "924","927", "928", "929", "930", "932"]
participants = ["909", "910", "912", "908"]

# %% [markdown]
# ## 3. Set up averaging

# %%
X,y,p,w,df = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="no_averaging")
Xt,yt,pt,wt,dft = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="average_trials")
Xa,ya,pa,wa,dfa = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="average_trials_and_participants")
# Out:
# loaded
#    909 910 912  908
# 1    0   1   1    2
# 2    2   0   1    1
# 3    1   0   1    3
# 4    1   0   0    3
# 5    0   1   1    1
# 6    2  -2   -    0
# 7    2   1   0    2
# 8    1   1   2    2
# 9    2   1   2    2
# 10   2   0   1    3
# 11   1   0   2    3
# 12   1   0   1    1
# 13   1   0   2    2
# 14   2   -   1    2
# 15   1   0   1    1
# 16   -   0   1    2
# 17   1   0   1    2
# 18   1   1   0    1
# 19   1   0   2    1
# 20   1   0   2    2
# 21   1   0   1    2
# 22   1   0   2    1
# 23   2   1   2    2
# 24   2   1   1    1
# 25   2   0   1    1
# 26   1   -   1    2
# 27   1   0   1    2
# 28   2   0   1    1
# 29   2   0   2    2
# 30   2   0   2    2
# 31   1   0   1    2
# 32   1   0   1    2
# loaded
#    909 910 912  908
# 1    0   1   1    2
# 2    2   0   1    1
# 3    1   0   1    3
# 4    1   0   0    3
# 5    0   1   1    1
# 6    2  -2   -    0
# 7    2   1   0    2
# 8    1   1   2    2
# 9    2   1   2    2
# 10   2   0   1    3
# 11   1   0   2    3
# 12   1   0   1    1
# 13   1   0   2    2
# 14   2   -   1    2
# 15   1   0   1    1
# 16   -   0   1    2
# 17   1   0   1    2
# 18   1   1   0    1
# 19   1   0   2    1
# 20   1   0   2    2
# 21   1   0   1    2
# 22   1   0   2    1
# 23   2   1   2    2
# 24   2   1   1    1
# 25   2   0   1    1
# 26   1   -   1    2
# 27   1   0   1    2
# 28   2   0   1    1
# 29   2   0   2    2
# 30   2   0   2    2
# 31   1   0   1    2
# 32   1   0   1    2
# loaded
#    909 910 912  908
# 1    0   1   1    2
# 2    2   0   1    1
# 3    1   0   1    3
# 4    1   0   0    3
# 5    0   1   1    1
# 6    2  -2   -    0
# 7    2   1   0    2
# 8    1   1   2    2
# 9    2   1   2    2
# 10   2   0   1    3
# 11   1   0   2    3
# 12   1   0   1    1
# 13   1   0   2    2
# 14   2   -   1    2
# 15   1   0   1    1
# 16   -   0   1    2
# 17   1   0   1    2
# 18   1   1   0    1
# 19   1   0   2    1
# 20   1   0   2    2
# 21   1   0   1    2
# 22   1   0   2    1
# 23   2   1   2    2
# 24   2   1   1    1
# 25   2   0   1    1
# 26   1   -   1    2
# 27   1   0   1    2
# 28   2   0   1    1
# 29   2   0   2    2
# 30   2   0   2    2
# 31   1   0   1    2
# 32   1   0   1    2

# %%
# (n, d) = X.shape
# assert n == y.shape[0]
# n

# %%
# unique, counts = np.unique(y, return_counts=True)
# dict(zip(unique, counts))

# %%
# (n, d) = Xt.shape
# assert n == yt.shape[0]
# n

# %%
# unique, counts = np.unique(yt, return_counts=True)
# dict(zip(unique, counts))

# %%
# (n, d) = Xa.shape
# assert n == ya.shape[0]
# n

# %%
# unique, counts = np.unique(ya, return_counts=True)
# dict(zip(unique, counts))

# %% [markdown]
# ## 4. Setting up the SVM model ...

# %%
model = LinearSVC(C=1e-9, max_iter=5000)

# %% [markdown]
# ## 5. Training and testing the model ...

# %% [markdown]
# ### 5.1. Train on raw, test on raw (validation)

# %%
# from sklearn import preprocessing

# scaler = preprocessing.StandardScaler().fit(X)
# X,Xp = scaler.transform(X), scaler.transform(Xp)
model.fit(X, y)
np.mean(model.predict(X) != y)
# Out:
# 0.16447368421052633

# %% [markdown]
# ### 5.2. Train on raw, test on avg by trial (word repetition)

# %%
# from sklearn import preprocessing

# scaler = preprocessing.StandardScaler().fit(X)
# X,Xp = scaler.transform(X), scaler.transform(Xp)
model.fit(X, y)
np.mean(model.predict(Xt) != yt)
# Out:
# 0.5625

# %% [markdown]
# ### 5.3. Train on raw, test on avg by word and ps

# %%
# from sklearn import preprocessing

# scaler = preprocessing.StandardScaler().fit(X)
# X,Xp = scaler.transform(X), scaler.transform(Xp)
model.fit(X, y)
np.mean(model.predict(Xa) != ya)
# Out:
# 0.625

# %% [markdown]
# # 13 month olds

# %% [markdown]
# # 2. Importing 13-Month-Olds..

# %%
#participants = ["105", "106", "107", "109", "111", "112", "115", "116", "117", "119", "121", "122", "120", "124"]
# participants = ["109", "111", "112", "115", "116", "117", "119", "121", "122", "120", "124"]

# %% [markdown]
# ## 3. Set up averaging

# %%
# X,y,p,w,df = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="no_averaging")
# Xt,yt,pt,wt,dft = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="average_trials")
# Xa,ya,pa,wa,dfa = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="average_trials_and_particpants")
# Out:
# loaded
#     109 111  112  115  116 117 119 121  122 120  124
# 1     1   3    2    3    2   -   2   0    2   1    3
# 2     3   1    2    4    0   0   0   1    2   0    4
# 3     3   1    0    4    0   1   2   0    1   0    3
# 4     3   1    3    4    0   2   1   0    1   1    2
# 5     3   0    1    3    0   2   2   0    1   1    3
# 6     3   3    3    3    1   0   0   0    1   1    3
# 7     3   2    2    3    1   1   1   0    1   1    4
# 8     2   1    2    4    1   1   1   -    1   0    3
# 9     3   2    0    2    1   2   0   -    2   0    3
# 10    4   3    2    4    1   1   0   1    1   -    3
# 11    1   3    1    4    0   2   1   0    2   1    2
# 12    3   0    1    4    2   0   2   1    1   -    3
# 13    3   2    2    3    2   1   1   -    0   0    3
# 14    3   0    3    3    2   1   1   0    1   1    4
# 15    2   1    2    2    0   1   -   -    0   1    4
# 16    2   -    1    4    1   0   0   0    2   1    2
# 17    3   3    3    2    0   2   -   1    1   1    2
# 18    2   3    3    5    1   1   1   1    1   1    1
# 19    2   2    3    3    1   1   1   0    1   0    3
# 20    4   0    2    3    1   1   0   0    2   -    4
# 21    3   1    1    4    1   1   1   -    2   0    3
# 22    2   1    3    0    0   1   0   0    1   0    3
# 23    3   3    1    2    0   1   0   0    0   1    3
# 24    1   1    0    4    1   2   1   -    2   2    3
# 25    2   0    3    4    1   1   -   0    1   -    2
# 26    3   1    2    3    1   1   2   0    0   1    3
# 23    3   3    1    2    0   1   0   0    0   1    3
# 24    1   1    0    4    1   2   1   -    2   2    3
# 25    2   0    3    4    1   1   -   0    1   -    2
# 26    3   1    2    3    1   1   2   0    0   1    3
# 27    2   2    1    3    0   -   0   -    2   1    3
# 28    4   1    3    4    2   2   2   0    1   0    3
# 29    2   2    1    3    1   0   1   0    2   0    3
# 30    3   2    1    3    1   2   1   -    1   0    3
# 31    4   0    3    2    1   1   0   0    1   1    4
# 32    3   3    1    3    1   1   0   0    0   2    3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-be0a71d88f61> in <module>
#       1 X,y,p,w,df = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="no_averaging")
#       2 Xt,yt,pt,wt,dft = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="average_trials")
# ----> 3 Xa,ya,pa,wa,dfa = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="average_trials_and_particpants")
#
# ~/Desktop/Studies/Animates EEG/8_Github/jwlab_eeg/classification/notebooks/../code/jwlab/ml_prep.py in prep_ml(filepath, participants, downsample_num, averaging)
#      24 def prep_ml(filepath, participants, downsample_num=1000, averaging="average_trials"):
#      25     df, ys = load_ml_data(filepath, participants)
# ---> 26     return prep_ml_internal(df, ys, participants, downsample_num=downsample_num, averaging=averaging)
#      27
#      28
#
# ~/Desktop/Studies/Animates EEG/8_Github/jwlab_eeg/classification/notebooks/../code/jwlab/ml_prep.py in prep_ml_internal(df, ys, participants, downsample_num, averaging)
#     118                 X, y, p, w = average_trials_and_participants(df, participants)
#     119             else:
# --> 120                 raise ValueError("Unsupported averaging!")
#     121
#     122             y[y < 8] = 0
#
# ValueError: Unsupported averaging!

# %%
# (n, d) = X.shape
# assert n == y.shape[0]
# n
# Out:
# 573

# %%
# unique, counts = np.unique(y, return_counts=True)
# dict(zip(unique, counts))
# Out:
# {0.0: 289, 1.0: 284}

# %%
# (n, d) = Xt.shape
# assert n == yt.shape[0]
# n
# Out:
# 176

# %%
# (n, d) = Xa.shape
# assert n == ya.shape[0]
# n
# Out:
# 16

# %%
# (n, d) = Xa.shape
# (n,d)
# Out:
# (16, 60000)

# %% [markdown]
# ## 4. Setting up the SVM model ...

# %%
# model = LinearSVC(C=1e-9, max_iter=1000)

# %% [markdown]
# ## 5. Training and testing the model ...

# %% [markdown]
# ### 5.1. Train on raw, test on raw (validation)

# %%
# # from sklearn import preprocessing

# # scaler = preprocessing.StandardScaler().fit(X)
# # X,Xp = scaler.transform(X), scaler.transform(Xp)
# model.fit(X, y)
# np.mean(model.predict(X) != y)
# Out:
# 0.21291448516579406

# %% [markdown]
# ### 5.2. Train on raw, test on avg by trial (word repetition)

# %%
# # from sklearn import preprocessing

# # scaler = preprocessing.StandardScaler().fit(X)
# # X,Xp = scaler.transform(X), scaler.transform(Xp)
# model.fit(X, y)
# np.mean(model.predict(Xt) != yt)
# Out:
# 0.5056818181818182

# %% [markdown]
# ### 5.3. Train on raw, test on avg by word and ps

# %%
# # from sklearn import preprocessing

# # scaler = preprocessing.StandardScaler().fit(X)
# # X,Xp = scaler.transform(X), scaler.transform(Xp)
# model.fit(X, y)
# np.mean(model.predict(Xa) != ya)
# Out:
# 0.5625

# %% [markdown]
# # All kids

# %% [markdown]
# ## 2. Importing all kids

# %%
#participants = ["904", "905", "906", "909", "910", "912", "908", "913", "914", "916", "917", "919", "920", "921", "923", "924","105", "106", "107", "109", "111", "112", "115", "116", "117", "119", "121", "122", "120"]
# participants = [ "909", "910", "912", "908", "913", "914", "916", "917", "919", "920", "921", "923", "924", "109", "111", "112", "115", "116", "117", "119", "121", "122", "120"]

# %% [markdown]
# ## 3. Set up averaging

# %%
# X,y,p,w,df = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging
#
#     117  119  121 122 120
# 1     -    2    0   2   1
# 2     0    0    1   2   0
# 3     1    2    0   1   0
# 4     2    1    0   1   1
# 5     2    2    0   1   1
# 6     0    0    0   1   1
# 7     1    1    0   1   1
# 8     1    1    -   1   0
# 9     2    0    -   2   0
# 10    1    0    1   1   -
# 11    2    1    0   2   1
# 12    0    2    1   1   -
# 13    1    1    -   0   0
# 14    1    1    0   1   1
# 15    1    -    -   0   1
# 16    0    0    0   2   1
# 17    2    -    1   1   1
# 18    1    1    1   1   1
# 19    1    1    0   1   0
# 20    1    0    0   2   -
# 21    1    1    -   2   0
# 22    1    0    0   1   0
# 23    1    0    0   0   1
# 24    2    1    -   2   2
# 25    1    -    0   1   -
# 26    1    2    0   0   1
# 27    -    0    -   2   1
# 28    2    2    0   1   0
# 29    0    1    0   2   0
# 30    2    1    -   1   0
# 31    1    0    0   1   1
# 32    1    0    0   0   2
#
# [32 rows x 23 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-be0a71d88f61> in <module>
#       1 X,y,p,w,df = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="no_averaging")
#       2 Xt,yt,pt,wt,dft = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="average_trials")
# ----> 3 Xa,ya,pa,wa,dfa = prep_ml(cleaned_data_filepath, participants, downsample_num=1000, averaging="average_trials_and_particpants")
#
# ~/Desktop/Studies/Animates EEG/8_Github/jwlab_eeg/classification/notebooks/../code/jwlab/ml_prep.py in prep_ml(filepath, participants, downsample_num, averaging)
#      24 def prep_ml(filepath, participants, downsample_num=1000, averaging="average_trials"):
#      25     df, ys = load_ml_data(filepath, participants)
# ---> 26     return prep_ml_internal(df, ys, participants, downsample_num=downsample_num, averaging=averaging)
#      27
#      28
#
# ~/Desktop/Studies/Animates EEG/8_Github/jwlab_eeg/classification/notebooks/../code/jwlab/ml_prep.py in prep_ml_internal(df, ys, participants, downsample_num, averaging)
#     118                 X, y, p, w = average_trials_and_participants(df, participants)
#     119             else:
# --> 120                 raise ValueError("Unsupported averaging!")
#     121
#     122             y[y < 8] = 0
#
# ValueError: Unsupported averaging!

# %%
# unique, counts = np.unique(y, return_counts=True)
# dict(zip(unique, counts))
# Out:
# {0.0: 562, 1.0: 575}

# %%
# X.shape
# Out:
# (1137, 60000)

# %% [markdown]
# ## 4. Setting up the SVM model ...

# %%
# model = LinearSVC(C=1e-9, max_iter=1000)

# %% [markdown]
# ## 5. Training and testing the model ...

# %% [markdown]
# ### 5.1. Train on raw, test on raw (validation)

# %%
# # from sklearn import preprocessing

# # scaler = preprocessing.StandardScaler().fit(X)
# # X,Xp = scaler.transform(X), scaler.transform(Xp)
# model.fit(X, y)
# np.mean(model.predict(X) != y)
# Out:
# 0.34036363636363637

# %% [markdown]
# ### 5.2. Train on raw, test on avg by trial (word repetition)

# %%
# # from sklearn import preprocessing

# # scaler = preprocessing.StandardScaler().fit(X)
# # X,Xp = scaler.transform(X), scaler.transform(Xp)
# model.fit(X, y)
# np.mean(model.predict(Xt) != yt)
# Out:
# 0.5603448275862069

# %% [markdown]
# ### 5.3. Train on raw, test on avg by word and ps

# %%
# # from sklearn import preprocessing

# # scaler = preprocessing.StandardScaler().fit(X)
# # X,Xp = scaler.transform(X), scaler.transform(Xp)
# model.fit(X, y)
# np.mean(model.predict(Xa) != ya)
# Out:
# 0.5625
